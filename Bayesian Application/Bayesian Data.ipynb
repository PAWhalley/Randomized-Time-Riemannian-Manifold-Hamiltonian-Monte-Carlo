# %%
import numpy as np
import pickle
import matplotlib.pyplot as plt
import numba

# %%
import os
from os import sys

# %%
data_matrix = np.zeros((120,2000))


for k in range(1,2001):
    file_location = './cov_shrink_simulations/'
    if k < 10:
        #print(k)
        file_name         =  'xi_athena_final_shrinkage_lognormal_2zbin_shapenoise_01_01_000' + str(k) + '.dat'
        file              =  os.path.join(file_location,file_name)
        dat_file          =  np.genfromtxt(fname=file,  skip_header =1, dtype='unicode', invalid_raise = False)
        xi_p              =  dat_file[:,1]
        xi_m              =  dat_file[:,2]
        xi_p              =  np.reshape(xi_p,(len(xi_p),1))
        xi_m              =  np.reshape(xi_m,(len(xi_m),1))
        temp1             =  np.append(xi_p,xi_m, axis = 0)
        
        file_name         =  'xi_athena_final_shrinkage_lognormal_2zbin_shapenoise_01_02_000' + str(k) + '.dat'
        file              =  os.path.join(file_location,file_name)
        dat_file          =  np.genfromtxt(fname=file,  skip_header =1, dtype='unicode', invalid_raise = False)
        xi_p              =  dat_file[:,1]
        xi_m              =  dat_file[:,2]
        xi_p              =  np.reshape(xi_p,(len(xi_p),1))
        xi_m              =  np.reshape(xi_m,(len(xi_m),1))
        temp2             =  np.append(xi_p,xi_m, axis = 0)
        
        file_name         =  'xi_athena_final_shrinkage_lognormal_2zbin_shapenoise_02_02_000' + str(k) + '.dat'
        file              =  os.path.join(file_location,file_name)
        dat_file          =  np.genfromtxt(fname=file,  skip_header =1, dtype='unicode', invalid_raise = False)
        xi_p              =  dat_file[:,1]
        xi_m              =  dat_file[:,2]
        xi_p              =  np.reshape(xi_p,(len(xi_p),1))
        xi_m              =  np.reshape(xi_m,(len(xi_m),1))
        temp3             =  np.append(xi_p,xi_m, axis = 0)   
    
    if 10 <= k < 100:
        #print(k)
        file_name         =  'xi_athena_final_shrinkage_lognormal_2zbin_shapenoise_01_01_00' + str(k) + '.dat'
        file              =  os.path.join(file_location,file_name)
        dat_file          =  np.genfromtxt(fname=file,  skip_header =1, dtype='unicode', invalid_raise = False)
        xi_p              =  dat_file[:,1]
        xi_m              =  dat_file[:,2]
        xi_p              =  np.reshape(xi_p,(len(xi_p),1))
        xi_m              =  np.reshape(xi_m,(len(xi_m),1))
        temp1             =  np.append(xi_p,xi_m, axis = 0)
        
        file_name         =  'xi_athena_final_shrinkage_lognormal_2zbin_shapenoise_01_02_00' + str(k) + '.dat'
        file              =  os.path.join(file_location,file_name)
        dat_file          =  np.genfromtxt(fname=file,  skip_header =1, dtype='unicode', invalid_raise = False)
        xi_p              =  dat_file[:,1]
        xi_m              =  dat_file[:,2]
        xi_p              =  np.reshape(xi_p,(len(xi_p),1))
        xi_m              =  np.reshape(xi_m,(len(xi_m),1))
        temp2              =  np.append(xi_p,xi_m, axis = 0)
        
        file_name         =  'xi_athena_final_shrinkage_lognormal_2zbin_shapenoise_02_02_00' + str(k) + '.dat'
        file              =  os.path.join(file_location,file_name)
        dat_file          =  np.genfromtxt(fname=file,  skip_header =1, dtype='unicode', invalid_raise = False)
        xi_p              =  dat_file[:,1]
        xi_m              =  dat_file[:,2]
        xi_p              =  np.reshape(xi_p,(len(xi_p),1))
        xi_m              =  np.reshape(xi_m,(len(xi_m),1))
        temp3             =  np.append(xi_p,xi_m, axis = 0)   
        
    if 100 <= k < 1000:
        #print(k)
        file_name         =  'xi_athena_final_shrinkage_lognormal_2zbin_shapenoise_01_01_0' + str(k) + '.dat'
        file              =  os.path.join(file_location,file_name)
        dat_file          =  np.genfromtxt(fname=file,  skip_header =1, dtype='unicode', invalid_raise = False)
        xi_p              =  dat_file[:,1]
        xi_m              =  dat_file[:,2]
        xi_p              =  np.reshape(xi_p,(len(xi_p),1))
        xi_m              =  np.reshape(xi_m,(len(xi_m),1))
        temp1             =  np.append(xi_p,xi_m, axis = 0)
        
        file_name         =  'xi_athena_final_shrinkage_lognormal_2zbin_shapenoise_01_02_0' + str(k) + '.dat'
        file              =  os.path.join(file_location,file_name)
        dat_file          =  np.genfromtxt(fname=file,  skip_header =1, dtype='unicode', invalid_raise = False)
        xi_p              =  dat_file[:,1]
        xi_m              =  dat_file[:,2]
        xi_p              =  np.reshape(xi_p,(len(xi_p),1))
        xi_m              =  np.reshape(xi_m,(len(xi_m),1))
        temp2             =  np.append(xi_p,xi_m, axis = 0)
        
        file_name         =  'xi_athena_final_shrinkage_lognormal_2zbin_shapenoise_02_02_0' + str(k) + '.dat'
        file              =  os.path.join(file_location,file_name)
        dat_file          =  np.genfromtxt(fname=file,  skip_header =1, dtype='unicode', invalid_raise = False)
        xi_p              =  dat_file[:,1]
        xi_m              =  dat_file[:,2]
        xi_p              =  np.reshape(xi_p,(len(xi_p),1))
        xi_m              =  np.reshape(xi_m,(len(xi_m),1))
        temp3             =  np.append(xi_p,xi_m, axis = 0)  
        
    if 1000 <= k:
        #print(k)
        file_name         =  'xi_athena_final_shrinkage_lognormal_2zbin_shapenoise_01_01_' + str(k) + '.dat'
        file              =  os.path.join(file_location,file_name)
        dat_file          =  np.genfromtxt(fname=file,  skip_header =1, dtype='unicode', invalid_raise = False)
        xi_p              =  dat_file[:,1]
        xi_m              =  dat_file[:,2]
        xi_p              =  np.reshape(xi_p,(len(xi_p),1))
        xi_m              =  np.reshape(xi_m,(len(xi_m),1))
        temp1             =  np.append(xi_p,xi_m, axis = 0)
        
        file_name         =  'xi_athena_final_shrinkage_lognormal_2zbin_shapenoise_01_02_' + str(k) + '.dat'
        file              =  os.path.join(file_location,file_name)
        dat_file          =  np.genfromtxt(fname=file,  skip_header =1, dtype='unicode', invalid_raise = False)
        xi_p              =  dat_file[:,1]
        xi_m              =  dat_file[:,2]
        xi_p              =  np.reshape(xi_p,(len(xi_p),1))
        xi_m              =  np.reshape(xi_m,(len(xi_m),1))
        temp2             =  np.append(xi_p,xi_m, axis = 0)
        
        file_name         =  'xi_athena_final_shrinkage_lognormal_2zbin_shapenoise_02_02_' + str(k) + '.dat'
        file              =  os.path.join(file_location,file_name)
        dat_file          =  np.genfromtxt(fname=file,  skip_header =1, dtype='unicode', invalid_raise = False)
        xi_p              =  dat_file[:,1]
        xi_m              =  dat_file[:,2]
        xi_p              =  np.reshape(xi_p,(len(xi_p),1))
        xi_m              =  np.reshape(xi_m,(len(xi_m),1))
        temp3             =  np.append(xi_p,xi_m, axis = 0)  
        
    temp12  = np.append(temp1, temp2, axis = 0)
    temp123 = np.append(temp12,temp3, axis = 0)
    #print(np.shape(temp123))
    data_matrix[:,k-1]  = np.reshape(temp123,(len(temp123),))

# %%
N = 60

p =  N//6
d =  N
m =  p

n = N*2//3
Data = data_matrix[:N,:2000]

mean = np.mean(Data[:,:n],axis = 1)
var = np.var(Data[:,:n],axis = 1)

    
    
for i in range(2000):
    Data[:,i] -= mean
    Data[:,i] /= np.sqrt(var)

# %%
@numba.jit(nopython=True)
def matrix_vec_multiplication(A,x):
    v = np.zeros(len(A))
    
    for i in range(len(A)):
        for j in range(len(x)):
                v[i] += A[i][j] * x[j]
    return v


@numba.jit(nopython=True)
def dot_product(v1,v2):
    dot = 0
    for i in range(len(v1)):
        
        dot += v1[i]*v2[i]
        
    return dot


@numba.jit(nopython=True)
def vec_to_matrix(q):
    X = np.zeros((d,p))
    for i in range(d):
        for j in range(p):
            X[i,j] = q[j*d+i]
    return X


@numba.jit(nopython=True)
def matmul(matrix1,matrix2):
    a = matrix1.shape[0]
    b = matrix2.shape[1]
    c = matrix2.shape[0]
    rmatrix = np.zeros((a,b))
    for i in range(a):
        for j in range(b):
            for k in range(c):
                rmatrix[i,j] += matrix1[i,k] * matrix2[k,j]
    return rmatrix




@numba.jit(nopython=True)
def f(q):
    X = vec_to_matrix(q[:d*p])
    d_1 = q[d*p:d*p+p]
    d_2 = q[d*p+p:]
    
    D_1 = np.diag(d_1)
    D_2 = np.diag(d_2)
    
    Σ = matmul(matmul(X,D_1),np.transpose(X)) + D_2
    return Σ

# %%
filename = 'xnew.sav'
x_map = pickle.load(open(filename,'rb'))
x_map = f(x_map)*np.outer(np.sqrt(var),np.sqrt(var))

# %%
plt.matshow(x_map,cmap='jet', vmin = -1e-10, vmax = 9e-10)
plt.colorbar()
plt.savefig('MAP.pdf')
plt.show()

# %%
inv_map = np.linalg.inv(x_map)
plt.matshow(np.log(abs(inv_map)),cmap='jet', vmin = 12, vmax = 31)
plt.colorbar()
plt.savefig('log-MAP.pdf')
plt.show()

# %%
filename = 'xbayesian.sav'
x_bayesian = pickle.load(open(filename,'rb'))

# %%
plt.matshow(x_bayesian,cmap='jet', vmin = -1e-10, vmax = 9e-10)
plt.colorbar()
plt.savefig('bayesian.pdf')
plt.show()

# %%
inv_bayesian = np.linalg.inv(x_bayesian)
plt.matshow(np.log(abs(inv_bayesian)),cmap='jet',vmin = 12, vmax = 31)
plt.colorbar()
plt.savefig('log-bayesian.pdf')
plt.show()

# %%
mean1 = np.zeros(d)
for i in range(2000):
    mean1 += Data[:,i]/2000
    
x_true = np.zeros((d,d))
for i in range(2000):
    x = Data[:,i] - mean1
    x_true += np.outer(x,x)/2000

x_true *= np.outer(np.sqrt(var),np.sqrt(var))

# %%
inv_true = np.linalg.inv(x_true)
fig = plt.figure()
plt.matshow(np.log(abs(inv_true)),cmap='jet',vmin = 12, vmax = 31)
plt.colorbar()
plt.savefig('log-true.pdf')
plt.show()

# %%
plt.matshow(x_true,cmap='jet', vmin = -1e-10, vmax = 9e-10)
plt.colorbar()
plt.savefig('true.pdf')
plt.show()

# %% [markdown]
# # Norms

# %% [markdown]
# ### Frobenius

# %%
np.linalg.norm(x_map - x_true)/np.linalg.norm(x_true)
# Out:
# 0.4862594850033884

# %%
np.linalg.norm(x_bayesian - x_true)/np.linalg.norm(x_true)
# Out:
# 0.5213377691061939

# %%
np.linalg.norm(inv_map - inv_true)/np.linalg.norm(inv_true)
# Out:
# 1.850318735590076

# %%
np.linalg.norm(inv_bayesian - inv_true)/np.linalg.norm(inv_true)
# Out:
# 0.9245118604522901

# %% [markdown]
# ### Covariance metric of Forstner and Moonen

# %%
from scipy.linalg import eigh

eigvals= eigh(x_map, x_true, eigvals_only=True)

d_map = np.sqrt(np.sum(np.log(eigvals)**2))

print(d_map)
# Out:
# 15.251520374910388

# %%
eigvals= eigh(inv_map, inv_true, eigvals_only=True)

print('inverse check = ',np.sqrt(np.sum(np.log(eigvals)**2)) - d_map)
# Out:
# inverse check =  4.281019982954604e-12

# %%
eigvals = eigh(x_bayesian, x_true, eigvals_only=True)
d_bayesian = np.sqrt(np.sum(np.log(eigvals)**2))

print(d_bayesian)
# Out:
# 14.762416510244584

# %%
eigvals= eigh(inv_bayesian, inv_true, eigvals_only=True)

print('inverse check = ',np.sqrt(np.sum(np.log(eigvals)**2)) - d_bayesian)
# Out:
# inverse check =  4.973799150320701e-14

# %%
eigvals= eigh(x_map, x_true, eigvals_only=True)
print(eigvals)
# Out:
# [8.11443104e-03 7.09310115e-02 9.44999721e-02 1.45454802e-01
#  1.54779569e-01 1.65248081e-01 1.85838615e-01 2.45126053e-01
#  2.64483805e-01 2.97209314e-01 3.37360295e-01 3.42763102e-01
#  3.68120302e-01 3.84340670e-01 4.10026607e-01 4.36143814e-01
#  4.75411031e-01 4.86188017e-01 5.10968014e-01 5.34885088e-01
#  5.78203464e-01 5.97663697e-01 6.30624543e-01 6.58548775e-01
#  7.24052450e-01 7.32121820e-01 7.64516828e-01 8.01343126e-01
#  8.18886290e-01 8.57694896e-01 9.07839641e-01 9.39986556e-01
#  9.89626121e-01 1.01771528e+00 1.06313811e+00 1.15220364e+00
#  1.23463779e+00 1.31379914e+00 1.58049507e+00 1.73855598e+00
#  1.86812071e+00 2.08073832e+00 2.34389773e+00 2.50659979e+00
#  2.78670193e+00 2.87691556e+00 3.19315204e+00 3.79070103e+00
#  4.27598998e+00 4.85868235e+00 8.82995481e+00 1.64386686e+01
#  2.09008520e+01 2.71930683e+01 2.91893215e+01 5.54289816e+01
#  6.93451084e+01 1.36882885e+02 1.65198216e+02 1.95728196e+02]

# %%
plt.matshow(np.random.rand(d)*np.min(x_true)/10 + x_true,cmap='jet', vmin = -1e-10, vmax = 9e-10)
plt.colorbar()
plt.savefig('true.pdf')
plt.show()

# %%
filename = 'positions.sav'
position = pickle.load(open(filename,'rb'))

# %%
last_entry_list = []
last = 0
burn = 10000
for i in range(len(position)-burn):
    mat = f(position[i+burn])
    
    last += mat[0,-1]
    last_entry_list.append(last/(i+1))

# %%
plt.plot(last_entry_list)
plt.title('A random entry')
plt.xlabel('number of samples')
# Out:
# Text(0.5, 0, 'number of samples')

# %%
plt.matshow(np.log(abs(x_true - x_bayesian)),cmap='jet',vmin = -36, vmax = -21)
plt.colorbar()
plt.savefig('absolute-error.pdf')
plt.show()

# %%
burn = 0
num_of_events = 50000
Σ_SD = np.zeros((d,d))
for i in range(num_of_events-burn):
    Σ = f(position[i+burn])*np.outer(np.sqrt(var),np.sqrt(var))
    Σ_SD += ((Σ - x_bayesian)**2)/(num_of_events-burn)
Σ_SD = np.sqrt(Σ_SD)

# %%
plt.matshow(np.log(abs(Σ_SD/x_bayesian)),cmap='jet')
plt.colorbar()
plt.show()

# %%
plt.matshow(np.log(Σ_SD),cmap='jet',vmin = -36, vmax = -21)
plt.colorbar()
plt.savefig('standard-deviation.pdf')
plt.show()

# %% [markdown]
# # ESS

# %%
import statsmodels.api as sm

# %%
σ_1 = 2
σ_2 = 2


@numba.jit(nopython=True)
def U(q):
    
    X = vec_to_matrix(q[:d*p])
    
    d_1 = q[d*p:d*p+p]
    d_2 = q[d*p+p:]
    
    D_1 = np.diag(d_1)
    D_2 = np.diag(d_2)
    
    Σ = matmul(matmul(X,D_1),np.transpose(X)) + D_2
    Σ_inv = np.linalg.inv(Σ)
    
    #likelihood
    pot = 0.5*n*np.log(np.linalg.det(Σ)) + 0.5*n*p*np.log((2*np.pi))
    for i in range(n):
        Bx = matrix_vec_multiplication(Σ_inv,Data[:,i]-mean)
        pot += 0.5*dot_product(Data[:,i]-mean,Bx)
        
    #prior
    #don't need uniform prior because it's constant
    pot += 0.5*np.log(2*np.pi*(σ_1)**2)
    pot += 0.5*dot_product(d_1,d_1)/(σ_1)**2
    
    pot += 0.5*np.log(2*np.pi*(σ_2)**2)
    pot += 0.5*dot_product(d_2,d_2)/(σ_2)**2
    
    return pot

# %%
# ESS
U_list = np.zeros(len(position))
for i in range(len(position)):
    U_list[i] = U(position[i])

# %%
auto = sm.tsa.acf(U_list,nlags = len(U_list)//10)
plt.plot(auto)

IAC = np.sum(auto)
IAC = 2*IAC - 1
    
print('IAC=',IAC)
    
ESS_percent = 1/IAC
# Out:
# /home/s2110992/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/stattools.py:572: FutureWarning: fft=True will become the default in a future version of statsmodels. To suppress this warning, explicitly set fft=False.
#   FutureWarning
# IAC= 1041.591401015572

# %%
#print(ESS_percent)

# %%
burn = 10000
Σ_ave = np.zeros((d,d))
for i in range(num_of_events-burn):
    Σ_ave += f(position[i+burn])*np.outer(np.sqrt(var),np.sqrt(var))/(num_of_events-burn)
    #print(len(position[i+burn]))

# %%
np.linalg.norm(Σ_ave - x_true)/np.linalg.norm(x_true)
# Out:
# 0.5213377691061933

# %%
burn = 10000
Σ_inv = np.zeros((d,d))
for i in range(num_of_events-burn):
    Σ_inv += np.linalg.inv(f(position[i+burn])*np.outer(np.sqrt(var),np.sqrt(var)))/(num_of_events-burn)
    #print(len(position[i+burn]))

# %%
np.linalg.norm(inv_bayesian - inv_true)/np.linalg.norm(inv_true)
# Out:
# 0.9245118604522901

# %%
np.linalg.norm(Σ_inv - inv_true)/np.linalg.norm(inv_true)
# Out:
# 0.9026979028350481

# %%
plt.matshow(np.log(abs(Σ_inv)),cmap='jet',vmin = 12,vmax = 31)
plt.colorbar()
plt.savefig('log-bayesian.pdf')
plt.show()

# %%
d_list = np.zeros(len(position))
for i in range(len(position)):
    mat = f(position[i])*np.outer(np.sqrt(var),np.sqrt(var))
    eigvals = eigh(x_bayesian, mat, eigvals_only=True)
    d_mat = np.sqrt(np.sum(np.log(eigvals)**2))
    d_list[i] = d_mat
    
eigvals = eigh(x_bayesian, x_true, eigvals_only=True)
d = np.sqrt(np.sum(np.log(eigvals)**2))
print(d)
# Out:
# 14.762416510244584

# %%
plt.hist(d_list,bins=10)
plt.axvline(x=d,color = 'r')
plt.title('Covariance')
plt.savefig('Covariance.pdf')
plt.show()

# %%
print(np.mean(d_list))
# Out:
# 4.450542008908279

# %%
plt.plot(d_list)

# %%
fro_list = np.zeros(len(position))
for i in range(len(position)):
    mat = f(position[i])*np.outer(np.sqrt(var),np.sqrt(var))
    
    fro = np.linalg.norm(mat - x_bayesian)/np.linalg.norm(x_true)
    
    fro_list[i] = fro

# %%
plt.hist(fro_list,bins = 10)
plt.axvline(x=np.linalg.norm(x_bayesian - x_true)/np.linalg.norm(x_true),color = 'r')
plt.title('Frobenius')
plt.savefig('frobenius.pdf')
plt.show()

# %%
plt.plot(fro_list)

# %%
np.linalg.norm(x_bayesian - x_true)/np.linalg.norm(x_true)
# Out:
# 0.5213377691061939

# %%
print(list(position[-1]))
# Out:
# [-0.013149611827487471, 0.0028835159128577674, 0.07573821953939884, 0.03452619701367471, 0.11176621319061279, 0.14441202199469402, 0.11637560263169368, 0.0380416493074039, 0.19391438631950683, 0.05174631951201714, 0.23487022681370723, 0.22284097570182668, 0.1928283372978408, 0.19006327268844853, 0.20203282970795008, 0.15057749296072276, -0.07574907812179615, -0.057631399955013214, -0.1354715221913267, -0.12073693501090098, -0.011823018351505192, -0.03997847898542651, -0.008094629058005707, -0.041759198754521755, 0.021251499121143186, -0.06003319684831408, 0.017899217405780665, 0.05670184101114289, 0.04309531071224388, -0.07537336299336896, -0.05828663807460686, -0.01750548937140724, -0.027563490253785853, 0.08044009178521405, -0.017168069328051525,